# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from matplotlib import cm, colors
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import scipy.integrate as integrate

# Increase resolution for retina display
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# Load interactive widgets
import ipywidgets as widgets

#import ipyvolume as ipv

# Import special functions 
import scipy.special as spe
n = input("Enter the value of n : ")
l = input("Enter the value of l : ")

def psi_R(r,n,l):

    coeff = (2.0*(2.0)**(l+3/2) * spe.factorial((n-l)/2.0) /(spe.factorial((l+n+3)/2)))
    
    laguerre = spe.assoc_laguerre(2.0*r*r,(n-l)/2,l+1/2)

    eta = np.exp(-2.0*r*r+(r))/((1+np.exp(r))**2)
    
    return coeff * eta * (r)**(2.0*l+1) * laguerre *(-0.44)

r = np.linspace(0,5,1000)

R = psi_R(r,n,l)
print(n)

plt.plot(r, R**2, lw=3)

plt.xlabel('$r [a_0]$',fontsize=20)

plt.ylabel('$R_{nl}(r)$', fontsize=20)

plt.grid('True')

plt.show()
# Out:
# Enter the value of n : 4
# Enter the value of l : 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-1ee6568ee3ff> in <module>()
#      34 r = np.linspace(0,5,1000)
#      35
# ---> 36 R = psi_R(r,n,l)
#      37 print(n)
#      38
#
# <ipython-input-7-1ee6568ee3ff> in psi_R(r, n, l)
#      24 def psi_R(r,n,l):
#      25
# ---> 26     coeff = (2.0*(2.0)**(l+3/2) * spe.factorial((n-l)/2.0) /(spe.factorial((l+n+3)/2)))
#      27
#      28     laguerre = spe.assoc_laguerre(2.0*r*r,(n-l)/2,l+1/2)
#
# TypeError: can only concatenate str (not "float") to str
