# %%
# Walk3D . py
#3−D Random walk w i t h 3−D g r a p h
from visual import ∗
import random
random.seed ( None )
jmax = 1000
xx =yy = zz = 0.0
# Seed g e n e r a t o r , None => s y s t e m c l o c k
# Start at origin
graph1 = display( x =0 , y =0 , width = 600 , height = 600 , title = ’3D Random Walk’ , forward =(−0.6,−0.5, −1) )
# Curve , i t s p a r a m e t e r s and l a b e l s
pts = curve ( x= list ( range ( 0 , 100 ) ) , radius = 10.0 , color = color.yellow)
xax = curve ( x= list ( range ( 0 , 1500 ) ) , color = color.red , pos = [ (0,0,0) , ( 1500,0,0 ) ] , radius = 10.)
yax = curve ( x= list ( range ( 0 , 1500 ) ) , color = color.red , pos = [ (0,0,0 ) , ( 0,1500,0 ) ] , radius = 10.)
zax = curve ( x= list ( range ( 0 , 1500 ) ) , color = color.red , pos = [ (0,0,0) , (0,0,1500 ) ] , radius = 10.)
xname = label ( text = "X" , pos = ( 1000,150,0) ,box =0)
yname = label ( text = "Y" , pos = ( −100,1000,0) , box = 0 )
zname = label ( text = "Z" , pos = (100,0,1000) , box = 0 )

pts.x[0] = pts.y[0] = pts.z[0]=0
for i in range (1,100) :
  xx += ( random.random() − 0.5 ) ∗ 2 .
  yy += ( random.random() − 0.5 ) ∗ 2 .
  zz += ( random.random() − 0.5 ) ∗ 2 .
  pts.x[i] = 200∗ xx − 100
  pts.y[i] = 200∗yy − 100
  pts.z[i] = 200∗zz − 100
  rate(100)
print( "This walk’s distance R =" , sqrt( xx∗xx +yy∗yy +zz∗zz ) )
# Starting point
# −1 =< x =< 1
# −1 =< y =< 1
# −1 =< z =< 1
# Out:
#   File "<ipython-input-8-d9a9a52bce9a>", line 3
#     from visual import ∗
#                        ^
# SyntaxError: invalid character in identifier
